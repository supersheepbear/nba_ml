# %%
import pandas as pd
from datetime import datetime, timedelta
import os

# %%
date = datetime(2007,11,10)
date_str = date.strftime("%Y-%m-%d")
predate = date - timedelta(days=1)
predate_str = predate.strftime("%Y-%m-%d")

score_folder = r"E:\project\nba_bet\data\scoreboard"
stats_folder = r"E:\project\nba_bet\data\team_stats"

score_path = os.path.join(score_folder, date_str + ".csv")
stats_path = os.path.join(stats_folder, predate_str + ".csv")

# %%
if os.path.exists(score_path):
    score_f = pd.read_csv(score_path)
else:
    pass

# %%
score_f.head()
# Out:
#    Unnamed: 0        GAME_DATE_EST  GAME_SEQUENCE   GAME_ID     TEAM_ID  \
# 0           0  2007-11-10T00:00:00              1  20700079  1610612756
# 1           1  2007-11-10T00:00:00              1  20700079  1610612753
# 2           2  2007-11-10T00:00:00              2  20700080  1610612743
# 3           3  2007-11-10T00:00:00              2  20700080  1610612754
# 4           4  2007-11-10T00:00:00              3  20700081  1610612738
#
#   TEAM_ABBREVIATION TEAM_CITY_NAME TEAM_WINS_LOSSES  PTS_QTR1  PTS_QTR2  ...  \
# 0               PHX        Phoenix              5-2        34        25  ...
# 1               ORL        Orlando              5-2        27        16  ...
# 2               DEN         Denver              4-3        31        25  ...
# 3               IND        Indiana              3-3        46        28  ...
# 4               BOS         Boston              5-0        26        33  ...
#
# ...

# %%
if os.path.exists(stats_path):
    stats_f = pd.read_csv(stats_path)
else:
    pass

# %%
stats_f.head()
# Out:
#    Unnamed: 0     TEAM_ID            TEAM_NAME  GP  W  L  W_PCT   MIN   FGM  \
# 0           0  1610612737        Atlanta Hawks   5  2  3    0.4  48.0  33.2
# 1           1  1610612738       Boston Celtics   4  4  0    1.0  49.3  40.8
# 2           2  1610612766    Charlotte Bobcats   5  3  2    0.6  48.0  30.8
# 3           3  1610612741        Chicago Bulls   5  1  4    0.2  49.0  33.4
# 4           4  1610612739  Cleveland Cavaliers   6  3  3    0.5  48.0  36.3
#
#     FGA  ...  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# 0  75.8  ...         2         30       12        19        24
# 1  75.5  ...        22          9       20        13         5
# 2  74.6  ...        26         14       22         7        29
# 3  85.6  ...        10         22       24         8        27
# 4  85.0  ...        17         19       21        25        18
#
#    PLUS_MINUS_RANK  CFID             CFPARAMS        date   season
# ...

# %%
stats_f.to_dict()
# Out:
# {'Unnamed: 0': {1610612737: 0,
#   1610612738: 1,
#   1610612766: 2,
#   1610612741: 3,
#   1610612739: 4,
#   1610612742: 5,
#   1610612743: 6,
#   1610612765: 7,
#   1610612744: 8,
#   1610612745: 9,
#   1610612754: 10,
#   1610612746: 11,
#   1610612747: 12,
#   1610612763: 13,
#   1610612748: 14,
#   1610612749: 15,
#   1610612750: 16,
#   1610612751: 17,
#   1610612740: 18,
#   1610612752: 19,
#   1610612753: 20,
#   1610612755: 21,
#   1610612756: 22,
#   1610612757: 23,
#   1610612758: 24,
#   1610612759: 25,
#   1610612760: 26,
#   1610612761: 27,
#   1610612762: 28,
#   1610612764: 29},
#  'TEAM_NAME': {1610612737: 'Atlanta Hawks',
#   1610612738: 'Boston Celtics',
#   1610612766: 'Charlotte Bobcats',
#   1610612741: 'Chicago Bulls',
#   1610612739: 'Cleveland Cavaliers',
#   1610612742: 'Dallas Mavericks',
#   1610612743: 'Denver Nuggets',
#   1610612765: 'Detroit Pistons',
#   1610612744: 'Golden State Warriors',
#   1610612745: 'Houston Rockets',
# ...

# %%
stats_f.columns
# Out:
# Index(['Unnamed: 0', 'TEAM_ID', 'TEAM_NAME', 'GP', 'W', 'L', 'W_PCT', 'MIN',
#        'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA',
#        'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK', 'BLKA',
#        'PF', 'PFD', 'PTS', 'PLUS_MINUS', 'GP_RANK', 'W_RANK', 'L_RANK',
#        'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK',
#        'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK',
#        'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK', 'AST_RANK',
#        'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK', 'PFD_RANK',
#        'PTS_RANK', 'PLUS_MINUS_RANK', 'CFID', 'CFPARAMS', 'date', 'season'],
#       dtype='object')

# %%
#stats_f.drop(['Unnamed: 0', 'TEAM_ID', 'CFID', 'CFPARAMS'], axis=1, inplace=True)

# %%
stats_f.head()
# Out:
#    Unnamed: 0     TEAM_ID            TEAM_NAME  GP  W  L  W_PCT   MIN   FGM  \
# 0           0  1610612737        Atlanta Hawks   5  2  3    0.4  48.0  33.2
# 1           1  1610612738       Boston Celtics   4  4  0    1.0  49.3  40.8
# 2           2  1610612766    Charlotte Bobcats   5  3  2    0.6  48.0  30.8
# 3           3  1610612741        Chicago Bulls   5  1  4    0.2  49.0  33.4
# 4           4  1610612739  Cleveland Cavaliers   6  3  3    0.5  48.0  36.3
#
#     FGA  ...  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# 0  75.8  ...         2         30       12        19        24
# 1  75.5  ...        22          9       20        13         5
# 2  74.6  ...        26         14       22         7        29
# 3  85.6  ...        10         22       24         8        27
# 4  85.0  ...        17         19       21        25        18
#
#    PLUS_MINUS_RANK  CFID             CFPARAMS        date   season
# ...

# %%
score_f.head()
# Out:
#    Unnamed: 0        GAME_DATE_EST  GAME_SEQUENCE   GAME_ID     TEAM_ID  \
# 0           0  2007-11-10T00:00:00              1  20700079  1610612756
# 1           1  2007-11-10T00:00:00              1  20700079  1610612753
# 2           2  2007-11-10T00:00:00              2  20700080  1610612743
# 3           3  2007-11-10T00:00:00              2  20700080  1610612754
# 4           4  2007-11-10T00:00:00              3  20700081  1610612738
#
#   TEAM_ABBREVIATION TEAM_CITY_NAME TEAM_WINS_LOSSES  PTS_QTR1  PTS_QTR2  ...  \
# 0               PHX        Phoenix              5-2        34        25  ...
# 1               ORL        Orlando              5-2        27        16  ...
# 2               DEN         Denver              4-3        31        25  ...
# 3               IND        Indiana              3-3        46        28  ...
# 4               BOS         Boston              5-0        26        33  ...
#
# ...

# %%
score_f.iloc[::2].loc[:, "PTS"]
# Out:
# 0     106
# 2     113
# 4     112
# 6     101
# 8      94
# 10     93
# 12     82
# Name: PTS, dtype: int64

# %%
score_f.iloc[1::2].loc[:, "PTS"]
# Out:
# 1      96
# 3     106
# 5     101
# 7      71
# 9     118
# 11    100
# 13     91
# Name: PTS, dtype: int64

# %%
away_team_ids = score_f.iloc[::2].loc[:, "TEAM_ID"]
home_team_ids = score_f.iloc[1::2].loc[:, "TEAM_ID"]
home_team_win_series = ((score_f.iloc[::2].loc[:, "PTS"].reset_index(drop=True) - score_f.iloc[1::2].loc[:, "PTS"].reset_index(drop=True)) < 0).astype(int)

# %%
((score_f.iloc[::2].loc[:, "PTS"].reset_index() - score_f.iloc[1::2].loc[:, "PTS"].reset_index()) < 0).astype(int)
# Out:
#    index  PTS
# 0      1    0
# 1      1    0
# 2      1    0
# 3      1    0
# 4      1    1
# 5      1    1
# 6      1    1

# %%
stats_f = stats_f.set_index("TEAM_ID", drop=True)

# %%
home_frame.columns
# Out:
# Index(['TEAM_NAME', 'GP', 'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS',
#        'PLUS_MINUS', 'GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK',
#        'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK',
#        'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK',
#        'DREB_RANK', 'REB_RANK', 'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK',
#        'BLKA_RANK', 'PF_RANK', 'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK',
#        'date', 'season'],
#       dtype='object')

# %%
away_frame.columns
# Out:
# Index(['TEAM_NAME', 'GP', 'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS',
#        'PLUS_MINUS', 'GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK',
#        'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK',
#        'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK',
#        'DREB_RANK', 'REB_RANK', 'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK',
#        'BLKA_RANK', 'PF_RANK', 'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK'],
#       dtype='object')

# %%
home_frame = stats_f.loc[home_team_ids, :]
away_frame = stats_f.loc[away_team_ids, :]
home_frame.reset_index(inplace=True)

home_frame.drop(["Unnamed: 0", 'TEAM_ID', 'CFID', 'CFPARAMS'], axis=1, inplace=True)
away_frame.reset_index(inplace=True)
away_frame.drop(["Unnamed: 0", "date", "season", 'TEAM_ID', 'CFID', 'CFPARAMS'], axis=1, inplace=True)

# %%
combine_f = pd.concat([home_frame, away_frame], axis=1)

# %%
combine_f.loc[:, "Home-Team-Win"] = home_team_win_series

# %%
combine_f.to_csv("combine_test.csv")

# %%
combine_f
# Out:
#                 TEAM_NAME  GP  W  L  W_PCT   MIN   FGM   FGA  FG_PCT  FG3M  \
# 0           Orlando Magic   6  5  1  0.833  48.0  34.8  76.8   0.453  10.2
# 1          Indiana Pacers   5  3  2  0.600  49.0  36.8  85.4   0.431   7.2
# 2         New Jersey Nets   5  4  1  0.800  49.0  30.6  76.0   0.403   6.2
# 3           Chicago Bulls   5  1  4  0.200  49.0  33.4  85.6   0.390   4.6
# 4               Utah Jazz   6  4  2  0.667  48.0  40.7  82.3   0.494   4.2
# 5        Sacramento Kings   5  1  4  0.200  48.0  32.6  74.8   0.436   3.0
# 6  Portland Trail Blazers   5  2  3  0.400  48.0  37.4  81.0   0.462   5.0
#
#    ...  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  \
# 0  ...         5         8         4        25         14        1        24
# 1  ...         4        22         2         7         19       16        14
# 2  ...         2        28         1        22          9       20        13
# ...

# %%
a = pd.read_csv(r'E:/project/nba_bet/nba_bet/app/predict_wins/train_data.csv')

# %%
b = pd.read_csv(r'E:\project\NBA-Machine-Learning-Sports-Betting\Personal_Tests\data.csv')

# %%
a.shape
# Out:
# (16780, 105)

# %%
b.shape
# Out:
# (3308, 105)
